# %%
#authorising an application to access Twitter account data
import twitter
CONSUMER_KEY = "KyzDjs5WCddpASBOWvoygPu4I"
CONSUMER_SECRET = "AErLrmZkmKAaqZWv71X4HZobFIJxDEPrqyFPJQp20FkDy321jC"
OAUTH_TOKEN = "1075681790180904961-EuK5Ma6kOwfOVhgLwe2eIiPY8F0YcE"
OAUTH_TOKEN_SECRET = "t0KjauLt6cm3gtYg9ZohtPd7kTWSDiymQyjBtUs7ugYQp"
auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)
print(twitter_api)

# %%
twitter_api.trends.available()
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %%
#Retrieving trends
WORLD_WOE_ID = 1
ND_WOE_ID = 332471
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
nd_trends = twitter_api.trends.place(_id=ND_WOE_ID)

print(world_trends)
print()
print(nd_trends)
# Out:
# [{'trends': [{'name': '#ATEEZSPACE', 'url': 'http://twitter.com/search?q=%23ATEEZSPACE', 'promoted_content': None, 'query': '%23ATEEZSPACE', 'tweet_volume': 85803}, {'name': '#HelloFuture6thWin', 'url': 'http://twitter.com/search?q=%23HelloFuture6thWin', 'promoted_content': None, 'query': '%23HelloFuture6thWin', 'tweet_volume': 324905}, {'name': '#スノハロ生配信', 'url': 'http://twitter.com/search?q=%23%E3%82%B9%E3%83%8E%E3%83%8F%E3%83%AD%E7%94%9F%E9%85%8D%E4%BF%A1', 'promoted_content': None, 'query': '%23%E3%82%B9%E3%83%8E%E3%83%8F%E3%83%AD%E7%94%9F%E9%85%8D%E4%BF%A1', 'tweet_volume': 156257}, {'name': '#15Temmuz', 'url': 'http://twitter.com/search?q=%2315Temmuz', 'promoted_content': None, 'query': '%2315Temmuz', 'tweet_volume': 408183}, {'name': '#VS魂', 'url': 'http://twitter.com/search?q=%23VS%E9%AD%82', 'promoted_content': None, 'query': '%23VS%E9%AD%82', 'tweet_volume': 34653}, {'name': '禁錮7年', 'url': 'http://twitter.com/search?q=%E7%A6%81%E9%8C%AE7%E5%B9%B4', 'promoted_content': None,
# ...

# %%
#Displaying API responses as pretty-printed JSON
import json

print(json.dumps(world_trends, indent=1))
print
print(json.dumps(nd_trends, indent=1))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#ATEEZSPACE",
#     "url": "http://twitter.com/search?q=%23ATEEZSPACE",
#     "promoted_content": null,
#     "query": "%23ATEEZSPACE",
#     "tweet_volume": 85803
#    },
#    {
#     "name": "#HelloFuture6thWin",
#     "url": "http://twitter.com/search?q=%23HelloFuture6thWin",
#     "promoted_content": null,
#     "query": "%23HelloFuture6thWin",
#     "tweet_volume": 324905
#    },
#    {
#     "name": "#\u30b9\u30ce\u30cf\u30ed\u751f\u914d\u4fe1",
#     "url": "http://twitter.com/search?q=%23%E3%82%B9%E3%83%8E%E3%83%8F%E3%83%AD%E7%94%9F%E9%85%8D%E4%BF%A1",
#     "promoted_content": null,
#     "query": "%23%E3%82%B9%E3%83%8E%E3%83%8F%E3%83%AD%E7%94%9F%E9%85%8D%E4%BF%A1",
#     "tweet_volume": 156257
#    },
#    {
#     "name": "#15Temmuz",
#     "url": "http://twitter.com/search?q=%2315Temmuz",
#     "promoted_content": null,
#     "query": "%2315Temmuz",
#     "tweet_volume": 408183
#    },
#    {
#     "name": "#VS\u9b42",
# ...

# %%
#Computing the intersection of two sets of trends
world_trends_set = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

nd_trends_set = set([trend['name'] 
                     for trend in nd_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(nd_trends_set)

print(common_trends)
# Out:
# {'#ATEEZSPACE'}

# %%
#Collecting search results
# Import unquote to prevent url encoding errors in next_results
from urllib.parse import unquote


q='ATEEZSPACE'


count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']

# Iterate through 5 more batches of results by following the cursor
print(search_results['search_metadata'])
for _ in range(5):
    print("Length of statuses", len(statuses))

    try:
        print(search_results['search_metadata'])
        next_results = search_results['search_metadata']['next_results']

    except KeyError: # No more results when next_results doesn't exist
        break

    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in unquote(next_results[1:]).split("&") ])

    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {'completed_in': 0.101, 'max_id': 1415635916824133634, 'max_id_str': '1415635916824133634', 'next_results': '?max_id=1415635898889248768&q=ATEEZSPACE&count=100&include_entities=1', 'query': 'ATEEZSPACE', 'refresh_url': '?since_id=1415635916824133634&q=ATEEZSPACE&include_entities=1', 'count': 100, 'since_id': 0, 'since_id_str': '0'}
# Length of statuses 100
# {'completed_in': 0.101, 'max_id': 1415635916824133634, 'max_id_str': '1415635916824133634', 'next_results': '?max_id=1415635898889248768&q=ATEEZSPACE&count=100&include_entities=1', 'query': 'ATEEZSPACE', 'refresh_url': '?since_id=1415635916824133634&q=ATEEZSPACE&include_entities=1', 'count': 100, 'since_id': 0, 'since_id_str': '0'}
# Length of statuses 200
# ...

# %%
#Extracting text, screen names, and hashtags from tweets
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "Wooyoung e seonghwa mi spezzano #ATEEZSPACE",
#  "RT @shakinassforSKZ: Atinys actually using this #ateezspace to ask questions to Ateez https://t.co/HkRkeHZH86",
#  "A RISADA DO WOOYOUNG @ATEEZofficial #ATEEZ #\uc5d0\uc774\ud2f0\uc988 #ATEEZSPACE",
#  "His laugh  #ATEEZSPACE https://t.co/j4kxyRlhkj",
#  "RT @ateez_wd: *listening to #ateezspace right now* https://t.co/3m8jJm4iuI"
# ]
# [
#  "shakinassforSKZ",
#  "ATEEZofficial",
#  "ateez_wd",
#  "ATEEZofficial",
#  "tjddp1024"
# ]
# [
#  "ATEEZSPACE",
#  "ateezspace",
#  "ATEEZ",
#  "\uc5d0\uc774\ud2f0\uc988",
#  "ATEEZSPACE"
# ]
# [
#  "Wooyoung",
#  "e",
#  "seonghwa",
#  "mi",
#  "spezzano"
# ]

# %%
#Creating a basic frequency distribution from the words in tweets
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#ATEEZSPACE', 550), ('#에이티즈스페이스', 188), ('RT', 178), ('@ATEEZofficial', 121), ('#ATEEZ', 99), ('#에이티즈', 93), ('you', 34), ('to', 27), ('우영', 27), ('i', 27)]
#
# [('ATEEZofficial', 137), ('tjddp1024', 22), ('FLAIRHWA', 9), ('ATEEZUD', 8), ('TwitterKorea', 6), ('charlieisadilf', 5), ('seongsang7', 5), ('jjjbabyluw', 5), ('ATEEZofficialjp', 4), ('ateez_charts', 4)]
#
# [('ATEEZSPACE', 559), ('에이티즈스페이스', 188), ('ATEEZ', 102), ('에이티즈', 94), ('ateezspace', 23), ('TwitterSpaces', 15), ('エイティーズ', 8), ('TwitterSpace', 5), ('애이티즈', 1), ('梯子', 1)]

# %%
#Using prettytable to display tuples in a nice tabular format
from prettytable import PrettyTable

for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    pt = PrettyTable(field_names=[label, 'Count']) 
    c = Counter(data)
    [ pt.add_row(kv) for kv in c.most_common()[:10] ]
    pt.align[label], pt.align['Count'] = 'l', 'r' # Set column alignment
    print(pt)
# Out:
# +-------------------+-------+
# | Word              | Count |
# +-------------------+-------+
# | #ATEEZSPACE       |   550 |
# | #에이티즈스페이스 |   188 |
# | RT                |   178 |
# | @ATEEZofficial    |   121 |
# | #ATEEZ            |    99 |
# | #에이티즈         |    93 |
# | you               |    34 |
# | to                |    27 |
# | 우영              |    27 |
# | i                 |    27 |
# +-------------------+-------+
# +-----------------+-------+
# | Screen Name     | Count |
# +-----------------+-------+
# | ATEEZofficial   |   137 |
# | tjddp1024       |    22 |
# | FLAIRHWA        |     9 |
# | ATEEZUD         |     8 |
# | TwitterKorea    |     6 |
# | charlieisadilf  |     5 |
# | seongsang7      |     5 |
# | jjjbabyluw      |     5 |
# | ATEEZofficialjp |     4 |
# | ateez_charts    |     4 |
# +-----------------+-------+
# +------------------+-------+
# | Hashtag          | Count |
# +------------------+-------+
# | ATEEZSPACE       |   559 |
# ...

# %%
#Calculating lexical diversity for tweets
# A function for computing lexical diversity
def lexical_diversity(tokens):
    return 1.0*len(set(tokens))/len(tokens) 

# A function for computing the average number of words per tweet
def average_words(statuses):
    total_words = sum([ len(s.split()) for s in statuses ]) 
    return 1.0*total_words/len(statuses)

print(lexical_diversity(words))
print(lexical_diversity(screen_names))
print(lexical_diversity(hashtags))
print(average_words(status_texts))
# Out:
# 0.41223832528180354
# 0.3115264797507788
# 0.013013013013013013
# 9.315
